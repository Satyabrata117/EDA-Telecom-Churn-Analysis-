# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyabrata117/EDA-Telecom-Churn-Analysis-/blob/main/Telecom_churn_Analysis_capstone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**Satyabrata Sahoo

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Orange S.A., formerly known as France Télécom S.A., is a prominent French multinational telecommunications corporation. The Orange Telecom's Churn Dataset includes cleaned customer activity data and a churn label indicating whether a customer has canceled their subscription. The objective is to explore and analyze this data to identify crucial factors contributing to customer churn and propose effective recommendations for customer retention.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Orange Telecom grapples with customer churn in its subscription services. Leveraging the Orange Telecom's Churn Dataset, the goal is to analyze customer activity data and churn labels, identifying key factors contributing to attrition. The challenge involves discerning patterns and indicators associated with churn to inform targeted retention strategies. By addressing root causes, enhancing service quality, and implementing proactive measures, Orange Telecom aims to mitigate churn, ensuring sustained customer satisfaction, and reinforcing its position in the competitive telecommunications sector.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The project's overarching goal is to maximize company profit by minimizing customer churn. Through a detailed analysis, we aim to unearth the factors influencing churn, subsequently devising targeted strategies to retain customers. This involves understanding the nuanced elements affecting attrition, implementing initiatives to address identified challenges, and providing personalized offers based on customer preferences. The expected outcomes encompass a tangible reduction in churn rates, heightened customer satisfaction, and optimized profit margins. Additionally, the project seeks to establish a data-driven decision-making framework, fostering a culture of continual improvement. By aligning our efforts with these objectives, we aim to fortify the company's market position, enhance customer loyalty, and ensure sustained success in the competitive telecommunications landscape.Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
#import visualization packages
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#insert the data
telecom_df = pd.read_csv('/content/drive/MyDrive/Project data/Telecom_churn/Telecom Churn.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
telecom_df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
#Getting the shape of dataset with rows and columns
print(telecom_df.shape)
# Out:
# (3333, 20)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
telecom_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
telecom_df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(telecom_df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset is from the telecom industry and contains information about customer activities, such as area codes, plan details, call information, and whether a customer canceled their subscription (churn label). The dataset has 3333 rows and 20 columns, with no missing or duplicate values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
telecom_df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Dataset Describe
telecom_df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# There are 16 colomns.they are as follows
#
#
#
#
# State - all 51 state
#
#
#
#
# Account length - how long account has been active
#
#
#
#
# Area code - code no of area
#
#
#
# International plan - international plan activated or not
#
#
#
# Voice mail plan : voice mail plan activated or no
#
#
#
# Number vmail messages : no of voice mail massagess
#
#
#
# Total day minutes : total day minutes used
#
#
#
# Total day calls : total day call made
#
#
#
# Total day charge : total day charge
#
#
#
# Total eve minutes : total evening minutes
#
#
#
# Total eve calls : total evening calls
#
#
#
# Total eve charge : total evening charge
#
#
#
# Total night minutes : total night minute
#
#
#
# Total night calls : total night calls
#
#
#
# Total night charge : total night charge
#
#
#
# Total intl minutes : total international minutes used
#
#
#
# Total intl calls : no of international calls
#
#
#
# Total intl charge : total international charge
#
#
#
# Customer service calls :  no of costomer service call made
#
#
#
# Churn : customer churn (target varriable True = 1 , False = 0 )

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in telecom_df.columns:
    unique_values_count = telecom_df[column].nunique()
    print("Number of unique values in", column, "is", unique_values_count)
# Out:
# Number of unique values in State is 51
# Number of unique values in Account length is 212
# Number of unique values in Area code is 3
# Number of unique values in International plan is 2
# Number of unique values in Voice mail plan is 2
# Number of unique values in Number vmail messages is 46
# Number of unique values in Total day minutes is 1667
# Number of unique values in Total day calls is 119
# Number of unique values in Total day charge is 1667
# Number of unique values in Total eve minutes is 1611
# Number of unique values in Total eve calls is 123
# Number of unique values in Total eve charge is 1440
# Number of unique values in Total night minutes is 1591
# Number of unique values in Total night calls is 120
# Number of unique values in Total night charge is 933
# Number of unique values in Total intl minutes is 162
# Number of unique values in Total intl calls is 21
# Number of unique values in Total intl charge is 162
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Print the number of customers churning
print("No. of customers Churning:", telecom_df[telecom_df['Churn'] == True].Churn.count())
# Out:
# No. of customers Churning: 483

# %%
# Assign variables to churned data
churn_df = telecom_df[telecom_df['Churn'] == True]

# %%
# Print the total number of unique area codes
print("No of Unique Area Code:", telecom_df['Area code'].nunique())
# Out:
# No of Unique Area Code: 3

# %%
# Print the number of customers with international plan activated
print("No of customers with International plan activated:", telecom_df[telecom_df['International plan'] == 'Yes']['International plan'].count())
# Out:
# No of customers with International plan activated: 323

# %%
# Print the number of customers with voice mail plan activated
print("No of customers with Voice mail plan activated:", telecom_df[telecom_df['Voice mail plan'] == 'Yes']['Voice mail plan'].count())
# Out:
# No of customers with Voice mail plan activated: 922

# %%
# Display the churned data
print(churn_df)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# Calculate the percentage of total customers churning
print("Total no. of customers:", telecom_df.Churn.count())
perc_churn = (churn_df.Churn.count() / telecom_df.Churn.count()) * 100
print(f"Percentage of customer churning: {round(perc_churn, 2)}%")
# Out:
# Total no. of customers: 3333
# Percentage of customer churning: 14.49%

# %%
# Statewise customer churning
state_cust_churn = churn_df.groupby(['State'])['Churn'].value_counts().reset_index(name='Churn_customer')
print(state_cust_churn.sum())
print(state_cust_churn)
# Out:
# State             AKALARAZCACOCTDCDEFLGAHIIAIDILINKSKYLAMAMDMEMI...
# Churn                                                            51
# Churn_customer                                                  483
# dtype: object
#    State  Churn  Churn_customer
# 0     AK   True               3
# 1     AL   True               8
# 2     AR   True              11
# 3     AZ   True               4
# 4     CA   True               9
# 5     CO   True               9
# 6     CT   True              12
# 7     DC   True               5
# 8     DE   True               9
# 9     FL   True               8
# 10    GA   True               8
# 11    HI   True               3
# 12    IA   True               3
# 13    ID   True               9
# 14    IL   True               5
# 15    IN   True               9
# 16    KS   True              13
# 17    KY   True               8
# 18    LA   True               4
# 19    MA   True              11
# 20    MD   True              17
# ...

# %%
# Account length wise churn data
acc_len_churn = churn_df.groupby(['Account length'])['Churn'].value_counts().reset_index(name='values')
print(acc_len_churn.sum())
print(acc_len_churn)
# Out:
# Account length    17028
# Churn               164
# values              483
# dtype: int64
#      Account length  Churn  values
# 0                 1   True       1
# 1                 2   True       1
# 2                12   True       1
# 3                13   True       1
# 4                16   True       1
# ..              ...    ...     ...
# 159             208   True       1
# 160             209   True       1
# 161             212   True       1
# 162             224   True       1
# 163             225   True       1
#
# [164 rows x 3 columns]

# %%
 #Area Code wise churn Percentage
Area_code_churn_perc = (telecom_df.groupby(['Area code'])['Churn'].mean() * 100).reset_index()
Area_code_churn_perc
# Out:
#    Area code      Churn
# 0        408  14.558473
# 1        415  14.259819
# 2        510  14.880952

# %%
# Percentage of Customers with and without international Plan churning to other networks
intl_plan_churn = (telecom_df.groupby(['International plan'])['Churn'].mean() * 100).reset_index(name='Churn %')
print(intl_plan_churn)

# Total number of Customers churning with international plan
churn_intl_yes = churn_df[churn_df['International plan'] == 'Yes']
print(f"No of Customers churning having International plan is {churn_intl_yes['International plan'].value_counts()[0]}")

# Total number of Customers churning without international plan
churn_intl_no = churn_df[churn_df['International plan'] == 'No']
print(f"No of Customers churning without having International plan is {churn_intl_no['International plan'].value_counts()[0]}")
# Out:
#   International plan    Churn %
# 0                 No  11.495017
# 1                Yes  42.414861
# No of Customers churning having International plan is 137
# No of Customers churning without having International plan is 346

# %%
# Percentage of People with and without Voice mail Plan churning to other networks
vmail_plan_churn = (telecom_df.groupby(['Voice mail plan'])['Churn'].mean() * 100).reset_index(name='Churn %')
print(vmail_plan_churn)

# Total number of people churning with vmail plan
churn_vmail_yes = churn_df[churn_df['Voice mail plan'] == 'Yes']
print(f"No of Customers churning having vmail plan is {churn_vmail_yes['Voice mail plan'].value_counts()[0]}")

# Total number of people churning without vmail plan
churn_vmail_no = churn_df[churn_df['Voice mail plan'] == 'No']
print(f"No of Customers churning not having vmail plan is {churn_vmail_no['Voice mail plan'].value_counts()[0]}")
# Out:
#   Voice mail plan    Churn %
# 0              No  16.715056
# 1             Yes   8.676790
# No of Customers churning having vmail plan is 80
# No of Customers churning not having vmail plan is 403

# %%
# Customers churning having both International plan and Voice mail plan
churn_intl_vmail = churn_df[(churn_df['International plan'] == 'Yes') & (churn_df['Voice mail plan'] == 'Yes')]

# Print the number of customers churning with both plans
print(f"No of Customers churning with both International plan and Voice mail plan: {len(churn_intl_vmail)}")
# Out:
# No of Customers churning with both International plan and Voice mail plan: 36

# %%
# Customers churning having intl plan and vmail plan
intl_vmail_yes = churn_df[(churn_df['International plan'] == 'Yes') & (churn_df['Voice mail plan'] == 'Yes')]
if len(intl_vmail_yes) > 0:
    print(f"No of Customers churning having intl and vmail plan are {intl_vmail_yes['Churn'].value_counts().get(1, 0)}")
else:
    print("No customers churning with both intl plan and vmail plan.")

# Customers churning having no intl plan and no vmail plan
intl_vmail_no = churn_df[(churn_df['International plan'] == 'No') & (churn_df['Voice mail plan'] == 'No')]
if len(intl_vmail_no) > 0:
    print(f"No of Customers churning having no intl plan and no vmail plan are {intl_vmail_no['Churn'].value_counts().get(1, 0)}")
else:
    print("No customers churning with neither intl plan nor vmail plan.")

# Customers churning having intl plan but no vmail plan
intl_yes_vmail_no = churn_df[(churn_df['International plan'] == 'Yes') & (churn_df['Voice mail plan'] == 'No')]
if len(intl_yes_vmail_no) > 0:
    print(f"No of Customers churning having intl plan but no vmail plan are {intl_yes_vmail_no['Churn'].value_counts().get(1, 0)}")
else:
    print("No customers churning with intl plan but no vmail plan.")

# Customers churning having no intl plan but vmail plan
intl_no_vmail_yes = churn_df[(churn_df['International plan'] == 'No') & (churn_df['Voice mail plan'] == 'Yes')]
if len(intl_no_vmail_yes) > 0:
    print(f"No of Customers churning having no intl plan but vmail plan are {intl_no_vmail_yes['Churn'].value_counts().get(1, 0)}")
else:
    print("No customers churning with no intl plan but vmail plan.")
# Out:
# No of Customers churning having intl and vmail plan are 0
# No of Customers churning having no intl plan and no vmail plan are 0
# No of Customers churning having intl plan but no vmail plan are 0
# No of Customers churning having no intl plan but vmail plan are 0

# %%
# Poor Connectivity States
# States Sorted with respect to international and voice mail plan
state_intl_vmail_yes = intl_vmail_yes['State'].unique()
state_intl_vmail_no = intl_vmail_no['State'].unique()
state_intl_yes_vmail_no = intl_yes_vmail_no['State'].unique()
state_intl_no_vmail_yes = intl_no_vmail_yes['State'].unique()

# Intersection of 4 types of plan made
inter_1 = set(state_intl_vmail_yes).intersection(set(state_intl_vmail_no))
inter_2 = set(state_intl_yes_vmail_no).intersection(set(state_intl_no_vmail_yes))
Intersection = set(inter_1).intersection(set(inter_2))
print(f"List of poor connectivity states are: {list(Intersection)}")
# Out:
# List of poor connectivity states are: ['WV', 'GA', 'NJ', 'NC', 'MN', 'NV', 'SD', 'MI', 'KS', 'MA']

# %%
# Combining day, evening, and night calls, minutes, and charges
telecom_df['Total calls'] = telecom_df.loc[:, ['Total day calls', 'Total eve calls', 'Total night calls']].sum(axis=1)
telecom_df['Total mins'] = telecom_df.loc[:, ['Total day minutes', 'Total eve minutes', 'Total night minutes']].sum(axis=1)
telecom_df['Total charge'] = telecom_df.loc[:, ['Total day charge', 'Total eve charge', 'Total night charge']].sum(axis=1)

# Mins per call
telecom_df['min_per_call'] = telecom_df['Total mins'] / telecom_df['Total calls']

# Charge per min
telecom_df['charge_per_min'] = telecom_df['Total charge'] / telecom_df['Total mins']

# International mins per call
telecom_df['Intl_min_per_call'] = telecom_df['Total intl minutes'] / telecom_df['Total intl calls']

# International charge per min
telecom_df['Intl_charge_per_min'] = telecom_df['Total intl charge'] / telecom_df['Total intl minutes']

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Churn Distribution:
#
# The total number of churned customers is 483.
# Churn distribution was visualized, and it was found that approximately 14.5% of customers churned.
# You used a bar chart to illustrate this churn distribution.
# Churn Rate Based on International and Voice Mail Plans:
#
# A table or chart (not visible) was used to analyze the churn rate based on the combination of having an international plan and a voice mail plan.
# Notably, customers without both an international plan and a voice mail plan had a higher churn rate, approximately around 62%.
# In summary, while exploring the overall churn distribution, you further investigated the churn rate based on specific plans. The analysis revealed that customers without both an international plan and a voice mail plan are more likely to churn.
#
# For a more comprehensive analysis, you may consider creating visualizations that combine both aspects, such as a stacked bar chart or a grouped bar chart, to highlight the interaction between international plans, voice mail plans, and customer churn.
#
# If you have any specific questions or if there's more analysis you'd like to perform, feel free to provide additional details!

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#Dependent Column Value Counts
print(telecom_df.Churn.value_counts())
print(" ")

# Plotting Dependent Variable Value Counts
labels = ['Not Churn (%)', 'Churn (%)']
colors = ['#4CAF50', '#FF5733']  # Green and Orange colors
explode = (0, 0.1)  # Explode the 'Churn' slice for emphasis

plt.figure(figsize=(10, 6))
plt.pie(telecom_df['Churn'].value_counts(), labels=labels, autopct='%1.1f%%', colors=colors, explode=explode, startangle=90, shadow=True)
plt.title('Churn Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is drawn as a circle.
plt.show()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts serve as a powerful tool for visually representing the proportions of a whole, making them particularly effective when showcasing data that has been pre-calculated as a percentage of the total. Their simplicity and visual appeal make them an excellent choice for illustrating proportions or percentages in a straightforward and aesthetically pleasing manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pie chart, it's evident that a significant majority, 85.5% (2850 customers), have not churned, while 14.5% (483 customers) are marked as churned. While the overall churn percentage may seem relatively small at 14.5%, it's crucial to recognize the growth from an initial 1.45%. This substantial increase highlights the urgency for immediate action to address and mitigate churn, considering the potential impact on customer retention. Proactive measures may be necessary to understand and respond to the factors contributing to this rise in churn, ensuring the long-term health and satisfaction of the customer base.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It's crucial to figure out why some customers are leaving, as even though our churn rate is 14.5%, which is within the industry norm, any customer loss is not good for business. Acquiring new customers is tough, and when one customer leaves, they might take away 3-4 potential new customers. Word-of-mouth is powerful in influencing others. Understanding and addressing the reasons for churn is vital for making decisions that keep our customers happy and our business growing.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
for col in telecom_df.describe().columns:
    # Create subplots
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))

    # Histogram with KDE
    sns.histplot(telecom_df[col], ax=axes, kde=True, color='skyblue')

    # Set title
    axes.set_title("Distribution of " + col, fontsize=15)

    # Show the plot
    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histograms are an effective visual tool when the goal is to illustrate the distribution of a single variable. They take the form of a bar chart, displaying the frequency or count of data points within specific ranges. Particularly beneficial for continuous data like age, height, weight, or income, histograms offer insights into the shape of the distribution, revealing characteristics such as skewness or outliers. This visualization aids in identifying patterns or trends within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Analysis of the distribution charts reveals that all numerical columns exhibit a symmetric distribution, with the mean closely aligning with the median. This symmetry indicates a balanced spread of values around the central tendency. Additionally, the "Area code" column is identified as a categorical variable due to its limited set of three distinct values. Treating it as categorical allows for more appropriate analysis and interpretation of its impact on the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Histogram and Box plot cannot give us whole information regarding data. It's done just to see the distribution of the column data over the dataset.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Calculate average churn percentage by state
avg_churn_by_state = telecom_df.groupby('State')['Churn'].mean().sort_values(ascending=False)

# Plotting the bar plot
plt.figure(figsize=(15, 8))
sns.barplot(x=avg_churn_by_state.index, y=avg_churn_by_state * 100, palette='viridis')
plt.title('Average Churn Percentage by State')
plt.xlabel('State')
plt.ylabel('Average Churn Percentage')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()
# Out:
# <ipython-input-65-ac41b0be83f4>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_churn_by_state.index, y=avg_churn_by_state * 100, palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar Charts: Bar charts help us compare things, like sizes or frequencies, in different categories. They are handy for showing a lot of data in a small space.
#
# For Churn Analysis: We used a Bar Chart to easily see how much, on average, customers are churning in each state. It gives a quick and simple way to compare churn percentages across different states.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There are 51 states having different churn rates .
#
# CA, NJ ,TX , MD ,SC ,MI, MS, NV, WA, ME are the ones who have higher churn rate more than 20% which is more than 50% of average churn rate.
#
# And HI, AK, AZ, VA, IA, LA, NE, IL, WI, RI are the ones who have lower churn rate which is less than 10%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the data of state wise churning depicts that there are lot of states who are having average churn rate more than 20 % which needs to be studied and look for further analysis to decide which factor are causing the churn.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Set the figure size
plt.figure(figsize=(10, 6))

# Create a box plot with a different color palette
sns.boxplot(x='Churn', y='Account length', data=telecom_df, palette='Set1')

# Set the title and labels
plt.title('Account Length vs. Churn')
plt.xlabel('Churn')
plt.ylabel('Account Length')

# Display the plot
plt.show()
# Out:
# <ipython-input-68-af718dc61d46>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y='Account length', data=telecom_df, palette='Set1')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Boxplots: Boxplots offer a succinct summary of crucial statistical features within a dataset, such as the median, quartiles, and range. They prove valuable for identifying outliers, comparing multiple datasets, and gaining insights into data dispersion. Commonly employed in statistical analysis and data visualization, boxplots provide a comprehensive view of the dataset's statistical characteristics.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As from the above record, we can see that Two digit Account Length customers are churning with a number of 225 and Three digit Account Length customers are churning with a number of 256.
#
# So, their churning rate is high.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Customers with very short account lengths (1-9 days) show a low churn rate of around 8.3%, indicating they might be testing the service and leaving if not satisfied.
#
# For those with account lengths between 10 and 99 days, the churn rate is higher at 14%. This group includes newer customers (below 50 days) and others (55-99 days) who might not find their plans beneficial.
#
# Long-term customers (account length over 100 days) also experience churn, suggesting that some may leave due to a lack of additional offers or benefits.
#
# In summary, account length provides insights into why customers might churn, distinguishing between trial-phase dissatisfaction, early plan issues, and potential challenges in retaining long-term customers.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code for international plan vs churn
# Set the figure size
plt.figure(figsize=(8, 8))

# Create a countplot for International Plan with 'Churn' as hue
sns.countplot(x='International plan', hue='Churn', data=telecom_df, palette='pastel', legend=False)

# Set the title and labels
plt.title('Churn Analysis based on International Plan')
plt.xlabel('International Plan')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  the countplot is chosen for its simplicity, effectiveness in comparing categorical counts, and its ability to convey the distribution of churned and non-churned customers across international plan categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this analysis, 3010 dont have an international plan, 323 have an international plan.
#
# Among those who have an international plan, 42.4 % people churn.
#
# Whereas among those who dont have an international plan, only 11.4 % people churn.
#
# Among those who have a international plan their average charge is 2.87 and they talk for 10.7 minutes on an average.
#
# Whereas among those who dont have a international plan their average charge is 2.75 and they talk for 10.16 minutes on an average.
#
# The reason why people having international plan might be leaving is that they are paying same amount of money for international calls as for those customers who dont have a international plan. Hence they arent getting any benefits for having an international plan so they might be unhappy.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights found will definitely help for a positive business impact. Those people who have international plan they are paying some additional charges to get the plan but the talk time value charge is same as those customers having no international plan. That might be great reason for more churns for those having international plan.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Calculate the counts of customers with and without voice mail plan
voice = telecom_df['Voice mail plan'].value_counts()

# Set a custom color palette
custom_palette = ['#66b3ff', '#99ff99']  # Example colors, you can customize these

# Styling parameters
explode = (0, 0.1)  # Explode the 'Yes' slice for emphasis
textprops = {'fontsize': 14, 'color': 'black'}

# Plotting styled pie chart for voice mail plan distribution
plt.figure(figsize=(10, 8))
plt.pie(voice, labels=['No', 'Yes'], explode=explode, colors=custom_palette, autopct="%1.1f%%", textprops=textprops,
        wedgeprops=dict(width=0.3, edgecolor='w'))  # Adding wedgeprops for a styled border
plt.title('Distribution of customers having voice mail plan', fontsize=18)
plt.show()

# %%
# Count of churned and non-churned customers with voice mail plan
churn_voice_mail = telecom_df[telecom_df['Voice mail plan'] == 'Yes']['Churn'].value_counts()

# Set color palette
colors = sns.color_palette('pastel')
textprops = {'fontsize': 14, 'color': 'black'}

# Plotting a stylish pie chart for customers churning with voice mail plan
plt.figure(figsize=(10, 8))
plt.pie(churn_voice_mail, labels=['Not Churned', 'Churned'], startangle=90, colors=colors, autopct="%1.1f%%", textprops=textprops,
        wedgeprops=dict(width=0.3, edgecolor='w'))  # Adding wedgeprops for a styled border
plt.title('Churn Analysis for Customers with Voice Mail Plan', fontsize=18)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are generally used to show the proportions of a whole, and are especially useful for displaying data that has already been calculated as a percentage of the whole.
#
# Thus, we have used pie chart to show the percentage of customers having voice mail plan.
#
# Bar charts are used to compare the size or frequency of different categories or groups of data. Bar charts are useful for comparing data across different categories, and they can be used to display a large amount of data in a small space.
#
# Thus, we have used bar chart to show the percentage of customers churned having voice mail plan.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# VOICE MAIL
#
# 2411 dont have a voice mail plan
#
# 922 have a voice mail plan
#
# Among those who dont have a voice mail 16.7 % people churn.
#
# Whereas among those who have a voice mail plan only 8.7 % people churn.
#
# *Customers with the Voice Mail Plan tend to churn less frequently*

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# es, voice mail plan might be considered partially.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Calculate average churn percentage for each Area Code
from matplotlib.ticker import FuncFormatter
area_code_churn_perc = telecom_df.groupby(['Area code'])['Churn'].mean().reset_index()

# Set color palette
colors = sns.color_palette('pastel')

# Plotting bar plot for Area Code wise average churn percentage with formatted x-axis ticks
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Area code', y='Churn', data=area_code_churn_perc, palette=colors)

# Format x-axis ticks as percentages
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y)))

plt.title('Area Code Wise Average Churn Percentage', fontsize=18)
plt.xlabel('Area Code')
plt.ylabel('Average Churn Percentage')
plt.ylim(0, 0.2)  # Set y-axis limit to ensure it's a percentage scale (0% to 20%)
plt.show()
# Out:
# <ipython-input-83-6c4a9a3bd24f>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Area code', y='Churn', data=area_code_churn_perc, palette=colors)
# <ipython-input-83-6c4a9a3bd24f>:11: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   ax = sns.barplot(x='Area code', y='Churn', data=area_code_churn_perc, palette=colors)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are used to compare the size or frequency of different categories or groups of data. Bar charts are useful for comparing data across different categories, and they can be used to display a large amount of data in a small space.
#
# To show the average percentage of true churn with respect to Area Code, we have used Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# All Area Code have around 14% Churn rate. So, Area Code doesn't matter.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# No, Area Code doesn't have any contribution to churn rate for 14% churn rate is same for all the area codes. But while furthur sagreggating the area codes with respective states in those area code, it can be analysed the states in which the issue is happeing. So, it has been defined above.
#
# So, here Area code won't help to create business impact but the respective states wise analysis can help.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code for the Table of average calls of total day, eve & night on basis of churn
# Create a pivot table to calculate average calls for total day, evening, and night based on churn status
calls_pivot = telecom_df.pivot_table(values=['Total day calls', 'Total eve calls', 'Total night calls'],
                                     index='Churn', aggfunc='mean')

# Display the pivot table
print(calls_pivot)
# Out:
#        Total day calls  Total eve calls  Total night calls
# Churn
# False       100.283158       100.038596         100.058246
# True        101.335404       100.561077         100.399586

# %%
# Create a pivot table to calculate average calls for total day, evening, and night based on churn status
calls_pivot = telecom_df.pivot_table(values=['Total day calls', 'Total eve calls', 'Total night calls'],
                                     index='Churn', aggfunc='mean').reset_index()

# Melt the pivot table for easier plotting
calls_melted = pd.melt(calls_pivot, id_vars='Churn', var_name='Call Type', value_name='Average Calls')

# Plotting the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Call Type', y='Average Calls', hue='Churn', data=calls_melted, palette='pastel')
plt.title('Average Calls for Total Day, Evening, and Night based on Churn')
plt.xlabel('Call Type')
plt.ylabel('Average Calls')
plt.show()

# %%
# Create a pivot table to calculate average minutes for total day, evening, and night based on churn status
minutes_pivot = telecom_df.pivot_table(values=['Total day minutes', 'Total eve minutes', 'Total night minutes'],
                                       index='Churn', aggfunc='mean')
# Display the pivot table
print(minutes_pivot)

# Create a pivot table to calculate average minutes for total day, evening, and night based on churn status
minutes_pivot = telecom_df.pivot_table(values=['Total day minutes', 'Total eve minutes', 'Total night minutes'],
                                       index='Churn', aggfunc='mean').reset_index()

# Melt the pivot table for easier plotting
minutes_melted = pd.melt(minutes_pivot, id_vars='Churn', var_name='Call Type', value_name='Average Minutes')

# Plotting the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Call Type', y='Average Minutes', hue='Churn', data=minutes_melted, palette='pastel')
plt.title('Average Minutes for Total Day, Evening, and Night based on Churn')
plt.xlabel('Call Type')
plt.ylabel('Average Minutes')
plt.show()
# Out:
#        Total day minutes  Total eve minutes  Total night minutes
# Churn
# False         175.175754         199.043298           200.133193
# True          206.914079         212.410145           205.231677

# %%
# Create a pivot table to calculate average charges for total day, evening, and night based on churn status
charges_pivot = telecom_df.pivot_table(values=['Total day charge', 'Total eve charge', 'Total night charge'],
                                       index='Churn', aggfunc='mean').reset_index()
print(charges_pivot)

# Melt the pivot table for easier plotting
charges_melted = pd.melt(charges_pivot, id_vars='Churn', var_name='Call Type', value_name='Average Charges')

# Plotting the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Call Type', y='Average Charges', hue='Churn', data=charges_melted, palette='pastel')
plt.title('Average Charges for Total Day, Evening, and Night based on Churn')
plt.xlabel('Call Type')
plt.ylabel('Average Charges')
plt.show()
# Out:
#    Churn  Total day charge  Total eve charge  Total night charge
# 0  False         29.780421         16.918909            9.006074
# 1   True         35.175921         18.054969            9.235528

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are used to compare the size or frequency of different categories or groups of data. Bar charts are useful for comparing data across different categories, and they can be used to display a large amount of data in a small space.
#
# Thus, we have used the bar plot to show the evening, night and day manipulated data to depict meaningful insights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Churn customers seem to talk more on the phone during the day, evening, and night, leading to higher charges compared to non-churn customers. To keep these churn customers happy and prevent them from leaving, a suggestion is to introduce a master plan. This plan could offer discounts, extra free minutes, or lower charges for customers who use more talk time. This way, it addresses the concerns of customers thinking about leaving due to high charges and provides them with better options. Implementing such a plan may not only keep existing customers satisfied but also attract new ones who appreciate flexibility in their phone usage. Before putting this plan into action, it's essential to carefully analyze its potential impact and feasibility.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# For telecom service provider calling and messaging are two essential product plans. Thus, optimizing voice call plans will definitely create a business impact. Those who are using just calling service must be provided some additional offers either in talktime or powerplus plan. Those who use voice call plan for night only, we might offer some exciting plans from midnight 12 to morning 6. For customers those who have higher accout length should be provided exciting offers as they are our loyal customers. Churing of higher account length customer will have a negative impact on business.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Calculate the churn rate per customer service calls
churn_rate_per_service_call = telecom_df.groupby('Customer service calls')['Churn'].mean() * 100

# Visualizing churn rate per customer service calls using a bar plot
plt.figure(figsize=(12, 9))
sns.barplot(x=churn_rate_per_service_call.index, y=churn_rate_per_service_call, color='skyblue')
plt.title("Churn Rate per Customer Service Call", fontsize=20)
plt.xlabel('Number of Customer Service Calls', fontsize=15)
plt.ylabel('Churn Rate (%)', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are used to compare the size or frequency of different categories or groups of data. Bar charts are useful for comparing data across different categories, and they can be used to display a large amount of data in a small space.
#
# Thus, we have used the bar plot to show the relationship between churn rate per customer service calls.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The analysis indicates that customers making more than 5 service calls are more likely to churn. To address this, it's crucial to promptly resolve queries and provide excellent service for this segment. Customers with four or more service calls churn more frequently, emphasizing the need for proactive customer support to enhance satisfaction and reduce churn rates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Customer service is an essential factor for every business. So definitely good customer service will have a positive impact to the business. We have to look after the customer calls and customer query report resolution duration. Need to optimize the time period. If one type of issue is coming from more than 5 customers, root cause analysis should be done on that same issue and should be resolved for everyone. Need to reduce the calls for each customer and he should be satisfied in a single call only. The customer service agents should be given great offer or recognition over great performance of customer issue resolution.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Calculate the correlation matrix
correlation_matrix = telecom_df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(15, 10))

# Create a heatmap using seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)

# Set the title of the plot
plt.title('Correlation Heatmap for Telecom Dataset', fontsize=16)

# Show the plot
plt.show()
# Out:
# <ipython-input-101-09e13a8841e4>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = telecom_df.corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation coefficient is a measure of the strength and direction of a linear relationship between two variables. A correlation matrix is used to summarize the relationships among a set of variables and is an important tool for data exploration and for selecting which variables to include in a model. The range of correlation is [-1,1].
#
# Thus to know the correlation between all the variables along with the correlation coeficients, we have used correlation heatmap

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above correlation heatmap, we can see total day charge & total day minute, total evening charge & total evening minute, total night charge & total night minute are positiveliy highly correlated with a value of 1.
#
# Customer service call is positively correlated only with area code and negative correlated with rest variables.
#
# Rest all correlation can be depicted from the above chart.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Your proposed solutions to reduce customer churn are thoughtful and cover various aspects of customer satisfaction and service improvement. Here's a concise summary of each point:
#
# Modify International Plan Pricing: Adjust the pricing of the International Plan to make it more competitive and attractive to customers.
#
# Proactive Communication: Initiate proactive communication with customers to understand their needs, address concerns, and build a stronger relationship.
#
# Feedback Gathering: Regularly seek feedback from customers to identify areas for improvement and gauge satisfaction levels.
#
# Periodic Offers: Introduce periodic offers and promotions to incentivize customer retention and showcase appreciation.
#
# Focus on Churning States: Identify and address challenges faced by customers in states with higher churn rates, tailoring solutions to meet specific needs.
#
# Engage Best Customers: Strengthen engagement with top-performing customers, offering personalized services and incentives to enhance loyalty.
#
# Regular Server Maintenance: Ensure the reliability and efficiency of services through regular server maintenance, reducing disruptions and enhancing customer experience.
#
# Network Connectivity Improvement: Address poor network connectivity issues promptly to enhance the overall quality of service.
#
# Customer Onboarding Roadmap: Develop a clear onboarding roadmap for new customers, ensuring a smooth transition and positive initial experiences.
#
# Churn Analysis: Continuously analyze churn patterns to gain insights into customer behavior, enabling strategic decision-making.
#
# Competitive Positioning: Stay competitive in the market by offering innovative services, competitive pricing, and staying attuned to industry trends.
#
# Implementing a combination of these strategies can contribute to a more robust customer retention approach. Keep monitoring customer feedback and performance metrics to refine and adapt your retention strategies over time.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The telecommunications market is already well-established, and the rate of new customers is slow. As a result, companies in this industry prioritize retention and reducing customer churn. This project analyzed a churn dataset to identify the main factors contributing to churn and gain valuable insights. Through exploratory data analysis, we were able to gain insight into the churn dataset, listed below:
#
# The four charge fields are directly related to the minute fields.
#
# The area code may not be relevant and can be excluded.
#
# Customers with the International Plan tend to churn more often.
#
# Customers who have had four or more customer service calls churn significantly more than other customers.
#
# Customers with high day and evening minute usage tend to churn at a higher rate.
#
# There is no clear relationship between churn and the variables such as day calls, evening calls, night calls, international calls, night minutes, international minutes, account length, or voice mail messages.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
